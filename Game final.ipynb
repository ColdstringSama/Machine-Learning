# %% [markdown]
# This game is based on the great movie Titanic. When I got moved by the selfless love between Jack and Rose, sometimes I would think, is there a chance that both could survive? In this game, the player can try to save Jack and Rose together. Due to space limitations, many plots have been deleted. The story ending is inspired by Charles Joughin and MythBusters.
# The game map can be visualized as follows:
# <br><br>
#
# ~~~
# Tavern--Deck--Dining Room--Crew Room--Sea--> Win
#       |     |                             |
#     ---------------------------------------> Fail
# ~~~
#
# <br>
# The resubmitted game includes more proper comments, 'else' to every 'if', explicit argument calls and case controlling for all user inputs, more random games for replay value, and less restrictive user inputs.

# %%
#Stage_1
def Tavern():
    # Introducing the main character's background
    print( 
"""
You are a poor artist called Jack.
Today, the famous Titanic is going to America
In a tavern, you see a bunch of people gambling.
Their bet is a third-class ticket for Titanic.
What are you going to do?
1) Join gambling
2) Go home    
""") 
    #Asking for player's input
    choice = str.lower(input(prompt = "Input your choice:\t"))
    #The misspelling 'gambl' is used for a broader user input 
    if choice == '1'or 'join' in choice or 'gambl' in choice:
        print("You only have the money for five games! Good luck!")
        money = 5
        # importing necessary packages
        import random
        # A little poker game. Player's 1 means one pair, 3 means full house. Opponent's 0 means nothing, 2 means two pairs. 
        # If the player is really unlucky, he/she can't win this game. The chance is 1/4^5, about 0.1%.
        user_lst=[1,3]
        opp_lst=[0,2]
        # Start of loop
        while money > 0:
            user_hand=random.choice(user_lst)
            opp_hand=random.choice(opp_lst)
            # Comparing user's card with opponent's card
            #When player has full house
            if user_hand > opp_hand and user_hand == 3:
                # When opponent has nothing
                if opp_hand == 0:
                    print("You get a full house in your hand, which is really good. Your opponent makes an all-in call, but he looks anxious and sweating.")
                #When the opponent has two pairs
                else:
                    print("You get a full house in your hand, which is really good. Your opponent makes an all-in call, he looks confident.")
                print( 
"""
What are you going to do?
1) All in
2) Fold
""") 
                #Asking for player's input
                choice = str.lower(input(prompt = "Input your choice:\t"))
                # Start of nested conditional
                if choice == '1'or 'all' in choice or 'in' in choice or 'bet' in choice or 'call' in choice:
                    print("Congratulations! You win the ticket!")
                    print("The tavernkeeper reminds you Titanic will go to America in five minutes.")
                    # Scenes changing
                    input(prompt ='<Press any key to hurry to the port!>\t')
                    Deck()
                    break
                elif choice =='2'or 'fold' in choice or 'give up' in choice:
                    #Decreasing the money
                    money = money-1
                    #Showing how many rounds left
                    print("You fold! "+str(money)+" rounds left!")
                    #Noticing this is the final round
                    if money == 1:
                        print("This is your final chance, good luck!")
                    else:
                        print("Good luck on next round!")
                # Error handling
                else:
                    print("Sorry, I don't understand your choice. Please try again.\n")
                # End of nested conditional
            # Comparing user's card with opponent's card
            # When the player has one pair but still higher
            elif user_hand > opp_hand and user_hand == 1:
                print("You get one pair in your hand, which is okay. Your opponent make a call of all in, but he looks anxious and sweating.")
                print( 
"""
What are you going to do?
1) All in
2) Fold
        
""") 
                #Asking for player's input
                choice = str.lower(input(prompt = "Input your choice:\t"))
                # Start of nested conditional
                if choice == '1'or 'all' in choice or 'in' in choice or 'bet' in choice or 'call' in choice:
                    print("You got one pair but your opponent got nothing. Congratulations! You win the ticket!")
                    print("The tavernkeeper reminds you Titanic will go to America in five minutes.")
                    # Scenes changing
                    input(prompt ='<Press any key to hurry to the port!>\n')
                    Deck()
                    break
            
                elif choice =='2'or 'fold' in choice or 'give up' in choice:
                    money = money-1
                    print("You fold! "+str(money)+" rounds left!")
                    if money == 1:
                        print("This is your final chance, good luck!")
                    # End of nested conditional
                    else:
                        print("Good luck on next round!")
                # Error handling
                else:
                    print("Sorry, I don't understand your choice. Please try again.\n")
                    
            else:
                print("You got one pair. Your opponent make a call of all in, he looks confident.")
                print( 
"""
What are you going to do?
1) All in
2) Fold
        
""") 
                #Asking for player's input
                choice = str.lower(input(prompt = "Input your choice:\t"))
                # Start of nested conditional
                if choice == '1'or 'all' in choice or 'in' in choice or 'bet' in choice or 'call' in choice:
                    print("You got one pair but your oppoent got two pairs.")
                    money = 0
                    break
                
                elif choice =='2'or 'fold' in choice or 'give up' in choice:
                    money = money-1
                    print("You fold! "+str(money)+" rounds left!")
                    if money == 1:
                        print("This is your final chance, good luck!")
                    else:
                        print("Good luck on next round!")
                # Error handling
                else:
                    print("Sorry, I don't understand your choice. Please try again.\n")
                # End of nested conditional
                        
        #When the player loses all the money, he loses the game
        while money <= 0:
            print("You lose all your money!")
            fail()
            break
        # End of loop    
        
    #When player chooses to go home, he fails    
    elif choice == '2'or 'home' in choice or 'go home' in choice:
        Bad_end1()
    
    # Easter Eggs based on my childhood games Warcraft & Starcraft cheating code
    elif choice == 'whosyourdaddy'or choice =='show me the money'or 'money' in choice or 'daddy' in choice:
        print(
"""
@@@@@@@@&@@@@@@@@@@@@@@@@@@@@@@@@&#/****/***,**,.,***(#&&&@@@@@@@@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&//(##%#*,***///*,,,,*(###%&&@@@@@@@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@@@@%%&&&(*#,..*,,,*///**,****/##&&&@@@@@@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@@&%%&&%%/*//**/////**//#%&%%#&&&&&%%%&@@@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@&(&@@&&%(/#&##%%%%(#(%(#%&&@@@@&&%%%%&&&&@@@@@@@@@@@@@@
(@@@@@@@@@@@@@@@@@@@@@@@@%#&@@&&&#(%@&####%&##((%(%&&&&&&%%%#&&@@@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@#%@@@@&&&&&(*,,*/((###%########((####&&@@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@%/****,,.....,,//////*//((###%%&@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&#(/******,,,,,,,,*,,/*,//((##%%%&@@&@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@&@@@@@%#(///****,,,..,,,,,,*(/**(###%%%&@@@@@@@@@@@@@@@
@@@@@@@@@@@@@@@@@@@@@@@@@&%@@@&&#(*////***,,,,,,,,,*///**/(###%%%%@@@@@@@@@@@@@%
@@@@@@@@@@@@@@@@@@@@@&&@&#(&&@@&%(/////***,,..,,,,*,,*,,*(%&&&&&%%%@@@@@@@@@@@&/
@@@@@@@@@@@@@@@@@@@@@@&@@&((%&&#(///**///(####/*,,****(#%%###%%&%%%@@@@@&&@@@@&/
##%%&*.,&@@@@@@@@@@@@@@@@@#*//%%///(#%%#((/(####(////(%&%%%##&%%#%%@@@@@&&&@@@%/
@@@@/...*/#@@@@@@&((#,*(*****,****///*/#&##(/(%##(*,*%########((##@@@@@@@@@@@@#/
@@@@@/,*/(//@@@@@/#@@&@@@@@@(**(((*****///(((/*,.,,.,(#((//***/((#&@@@@@@@@@&%(/
@@@@@@#(/*/(/***(#%%&&&&%%##/./*./**/,,,*/(.....,,,,.*####//**/(#%&@@@@@@@@&&%(/
@@@@@@@%(/*/(((#(((#%#(/   .*,...,**,,*/(/*,,*((,,*,,,(####%####%%&@@@@@@@@&&#((
@@@@@@@/,,.((#(//#&@&&@@&&&&&&&%##&&&%* .//(##(**#%#(#%%%%%%###%%%@@@@@@@@@@&#(/
@@@@@& ......... .,%@&@@@@@@@&%#*  /%%%///(#/*/*****/(#%%&%#((#%%&@@@@@@@@&&&#//
@@@@,***,,,***/**/#**(%&&%%%%&%%%%##&#(/*(**,,,,,*,,,**(#%%##%%&@@@@@@@@@@@&&#(/
@@@@(//((//#%%#(((((//*,.... .,#%*,.%%%%#((#(/****//(####(#%&&@@@@@@&%%%&@@@@&##
@@@@@/...,**,***,,,,,,,*,,,,***,***/%@@%%&&%#((//*,,,**/(#%&&(@@@@@@&&&&@@@@@&%%
@@@&&,..,,******////(((/./****/(%@@@@@@@@&&%%&&%#((((###%&&/((@@@@@@@@@@@@@@@&%%
@@@@@.///****///(((//////%##(&@@@@@@@@@@@@@*.%#@@@@&&&&@%&@@@@@@@@@@@@@@@@@@@@&&
@&&@/ &#(/,.,,*//(((((( *&&*@@@@@@@@@@@@@@@@&&&@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
@@@@. &%(#####(/*//((#&@&&&%&@@@@@@@@@@@@@@@@@%@@@@@@@&@@@@@@@@@@@@@@@@@@@@@@@@@
@@@@, /&%(#####%###(((@@@&&#@@@@@@@@@@@@@@@@@@@@@@@@@@%&#%@@@@@@@@@@@@@@@@@@@@@@
@@@@(  &%%#(((((/(&%,@@@@&&#@@@@@@@@@@@@@@@@@@@@@@&(**,,(/*/%&@@@@@@@@@@@@@@@@@@
@@@@@/  &&#//*//#/./@@@@@&&(@@@@@@@@@@@@@@@@@@@@@@@/......,,*%@@@@@@@@@@@@@@@@@@
@@@@@@#  %%###%,  #@@@@@@&&(&@@@@@@@@@@@@@@@@@@@@@@@@,   ...*%@@@@@@@@@@@@@@@@@@
@@@@@@@%  %&&#   @@@@@@@&#(##@@@@@@@@@@@@@@@@@@@@@@@@@#.    .*@@@@@@@@@@@@@@@@@@
@@@@@@@@(  &,  *@@%#/*.. ,,,/**,. ,(&@@@@@@@@@@@@@@@@@@&..   *&@@@@@@@@@@@@@@@@@
""")
        print("With the help of game maker! You win the ticket!")
        # Scenes changing
        input(prompt ='<Press any key to get on board!>\n')
        Deck()
    # Error handling
    else:
        print("Sorry, I don't understand your choice. Please try again.\n")
        input(prompt ='<Press any key to continue>\n')
        Tavern()
    

#Stage_2
def Deck():
    print( 
"""
You're on board! Welcome to the titanic!
You spend some time on the deck.
At evening, you see a crying beautiful lady running to the stern.
What are you going to do?
1) Follow her
2) Leave her alone    
""") 
    #Asking for player's input
    choice = str.lower(input(prompt = "Input your choice:\t"))
    #If the player doesn't follow Rose, she will jump into the sea
    if choice == '1' or 'follow' in choice:
        print("That young lady is standing outside of the guardrail. She seems to going to jump into the sea.")
        print("Press 1 to comfort her.")
        print("Press 2 to leave her alone.")
    
        #Asking for player's input
        choice = str.lower(input(prompt = "Input your choice:\t")) 
        
        if choice == '1' or 'comfort' in choice:
            #The player can say something nice to comfort her
            say = input(prompt = "Say something to comfort her:\t")
            print("You say: "+str(say)+" to her and you come closer to her.")
            print(
"""
But she refuses to come back over the rail.
So you take off your jacket and shoes. You are telling her how cold the water can be. 
You tell her you will jump too if she jumps.
She hesitates for a bit. Then she takes your hand so you can pull her back to the deck.
You know her name is Rose now.
""")
            input(prompt ='<Press any key to pull her back>\n')
            print("When you try to pull her back, her feet slip on the rail.")
            print("She almost falls into the sea.")
            print("You need to pull her up!!\n")
            #A little game to pull Rose up
            # importing necessary packages
            from random import randint
            presses = randint(2,5)
            #Start of loop
            while presses > 0:
                input(prompt ='<Press any key to pull harder!!>\n')
                presses -= 1
            #End of loop
            print("You pull her up!")
            print("Though her screaming brought in some sailors and sheriff, when they know what happened, they call you a hero.")
            print("Her fiance invites you for tomorrow dinner.")
            # Scenes changing
            input(prompt ='<Press any key to end this day>\n')
            Dining_Room()
            
        elif choice == '2'or 'leave' in choice:
            Bad_end2()
        
        else:
            print("You didn't act immediately. She jumps into the sea.")
            Bad_end2()

    elif choice == '2'or 'leave' in choice:
        Bad_end2()
    # Error handling
    else:
        print("Sorry, I don't understand your choice. Please try again.\n")
        Deck()
        
#Stage 3
#In this stage, the player can't fail, no matter what choice he/she makes will lead the player to stage 4 
def Dining_Room():
    print( 
"""
The next day morning, you meet Rose on the deck. She is surprised by your artistic talent.
You and Rose share experiences and stories and get a closer relationship.
Before you go to the dinner, a lovely noble lady lent you her son's suit. 
She said: You shine up like a new penny!
""")
    # Scenes changing
    input(prompt ='<Press any key to go to the dinner>\n')
    print(
"""
Rose's fiance doesn't like you. 
He asks you lots of questions about your background.
He tries to embarrass you in front of everyone during dinner.
What are you going to do?
1) Reply honestly and wisely.
2) Punch him with your fist.
3) Leave the dining room embarrassingly.   
""") 
    #Asking for player's input
    choice = str.lower(input(prompt = "Input your choice:\t"))
        
    if choice == '1' or 'reply' in choice or 'honest' in choice or 'wise' in choice:
        print( 
"""
You earn respect from many other nobles with your wisdom and sense of humor. 
After dinner, you have a good time with Rose.
You and Rose are in love with each other.
Her fiance set you up by putting a beautiful necklace in your pocket.
He claims that you stole it.
The sheriff takes you to a crew room and leaves you alone.
""") 
        # Scenes changing
        input(prompt ='<Press any key to continue>\n')
        Crew_Room()
        
    elif choice =='2' or 'punch' in choice or 'fist' in choice:
        print( 
"""
Attacking a noble in public is not wise enough.
The sheriff takes you to a crew room and leaves you alone.
""") 
        # Scenes changing
        input(prompt ='<Press any key to continue>\n')
        Crew_Room()
    elif choice =='3' or 'leave' in choice or 'walk away' in choice:
        print(
"""
You leave embarrassingly, and her fiance laughs at you loudly.
But anyway you have a good time with Rose on next day.
You and Rose are in love with each other.
Her fiance set you up by putting a beautiful necklace in your pocket.
He claims that you stole it.
The sheriff takes you to a crew room and leaves you alone.
""") 
        # Scenes changing
        input(prompt ='<Press any key to continue>\n')
        Crew_Room()
    # Error handling
    else:
        print("Sorry, I don't understand your choice. Please try again.\n")
        input(prompt ='<Press any key to continue>\n')
        Dining_Room()
        

#Stage_4
#In this stage, the player can't fail, no matter what choice he/she makes will lead the player to stage 5
def Crew_Room():
    print(
"""
You are handcuffed to a pipe.
You hear that there is a disturbance outside.
You find out there is more and more water coming into this room.
You think the ship is sinking!
""") 
    presses = 8
    water_level=10
    # A little game to create a tense atmosphere
    # Start of loop
    while presses > 4:
        input(prompt ='<Press any key to try escape!>\n')
        print("The water level is rising, now it's about "+str(water_level)+"% of the room")
        presses -= 1
        water_level +=10
    while presses == 4:
        print("You can't get rid of the handcuff.")
        print("But you heard Rose's voice! She's calling your name!")
        presses -= 1
    while presses > 0:
        # The player could shout out anything he/she wants
        respond = input(prompt ='<Say something to respond!>\n')
        print("You shout: "+str(respond)+"!")
        print("The water level is rising, now it's about "+str(water_level)+"% of the room")
        presses -= 1
        water_level +=10
    # End of loop
    print("Rose breaks into the room! She examines your handcuff, then she finds an axe and prepares to chop the handcuff off.")
    print("You find out that there are five scale bars on the pipe, which can help you maintain your handcuff position.")
    # A game to cut off handcuff
    # importing necessary packages
    from random import randint\
    # Setting the axe position
    axe_position = randint(1,5)
    # The player needs to move the handcuff to the right position to cut if off
    hand_position = int(input(prompt = "Input which scale bar you want to put your handcuff at, from 1 to 5:\t"))
    #Start of loop
    while hand_position != axe_position:
        if hand_position < axe_position:
            print("You think your handcuff a bit left to the axe.")
        elif hand_position > axe_position:
            print("You think your handcuff a bit right to the axe.")
        elif hand_position == axe_position:
            print("You think your handcuff is at the right position.")
        # Error handling
        else:
            print("Sorry, I don't understand your choice. Please try again.\n")
        hand_position = int(input(prompt = "Input which scale bar you want to put your handcuff at, from 1 to 5:\t"))
    #End of loop
    print("Rose cut off your handcuff. You are free!")
    # Scenes changing
    input(prompt ='<Press any key to escape from this room. It is almost full of water!>\n')
    Sea()
    
#Stage 5 \
#This is the final stage. 
#The player needs to make his/her choice carefully
#There are multiple paths to the good ending.
def Sea():
    #Reset the item.
    liqueur = 0 
    deck_chairs = 0
    print(
"""
Everyone is running for their lives! 
You see a chef throwing deck chairs overboard.
The orchestra is still playing music on the deck.
You get a life jacket from the ship designer.
""") 
    #That chef is Charles Joughin, the chief baker of Titanic who survived from the extreme cold in seawater for 2 hours.
    print( 
"""
What are you going to do?
1) Stop running and help the chef, follow him and throw some deck chairs too.
2) Go to the port of this ship to see if there is an available lifeboat left.
3) Gather items that you can see.        
""") 
    # Asking for player's input
    choice = str.lower(input(prompt = "Input your choice:\t"))
    # To reach the good ending, the key is to get something to warm the body up or get an extra flotation device,   
    if choice == '1' or 'chef' in choice or 'chairs' in choice:
        print("The chef thank you. He gives you a little bottle of liqueur.")
        liqueur = 1 
        deck_chairs = 1       
            
    elif choice =='2' or 'port' in choice or 'boat' in choice:
        print("Sadly that place is full of people, and there is no lifeboat left.")
        
    elif choice =='3' or 'item' in choice:
        # The key is to get liqueur to warm body up
        print("You found a bunch of stuff, but you can only carry two types of item.")
        print( 
"""
What are you going to give up?
1) A large bottle of liqueur
2) An oversized coat made of fur.
3) A lot of cash.
        
""") 
        #Asking for player's input
        choice = str.lower(input(prompt = "Input your choice of item to give up:\t"))
        # Start of nested conditional
        if choice == '1' or 'liqueur' in choice:
            print("You got what you want!")
        elif choice == '2' or 'fur' in choice:
            print("You got what you want!")
            liqueur = 1
        elif choice == '3' or 'cash' in choice:
            print("You got what you want!")
            liqueur = 1
        else:
            print("You spend too much time to decide which item to give up!")
        # End of nested conditional
    # Error handling
    else:
        print("Sorry, I don't understand your choice. Please try again.\n")
        input(prompt ='<Press any key to continue>\n')
        Sea()
    print("The titanic is almost sunk! You and Rose will fall into the freezing seawater in about five minutes.")
    print( 
"""
What are you going to do?
1) Try to find something as a flotation device around before falling into the sea.
2) Jump into the seawater from the ship now.
""") 
    #Asking for player's input
    choice = str.lower(input(prompt = "Input your choice:\t"))
            
    if choice == '1' or 'find' in choice or 'flotation' in choice and deck_chairs == 1:
        print("You got a floating wreckage and also some floating deck chairs!")
        print("When you fall into the freezing seawater, you let Rose stay on the wreckage.")
        print("You bind your floating chairs together and stay on them.")
        print("You also share the liqueur with Rose. It helps keep Rose's and your body warm.")
        Happy_end()
    elif choice == '1' or 'find' in choice or 'flotation' in choice:
        print("You got a floating wreckage! But it can only provide buoyancy for one person weight. ")
        print( 
"""
What are you going to do?
1) Try to bind your life jacket to the bottom of the wreckage to provide more buoyancy for two people.
2) Leave the space to Rose.
3) Push Rose into the sea.
""") 
        #Bind the life jacket to the bottom of the wreckage to provide more buoyancy for two people is proved by MythBusters.
        choice = str.lower(input(prompt = "Input your choice:\t"))
        # Start of nested conditional
        if choice == '1' or 'jacket' in choice or 'buoyancy' in choice and liqueur == 1:
            print("In this icy sea water, your hands are shaking. ")
            print("But luckily, your liqueur warms your body. ")
            print("You successfully bind your lifejacket to the bottom of the wreckage.")
            print("You get on the wreck too! You and Rose are hugging each other to keep warm.")
            Happy_end()
        elif choice == '1' or 'jacket' in choice or 'buoyancy' in choice:
            print("In this icy seawater, your hands are shaking badly. You failed to do so")
            Normal_end()
        elif choice == '2' or 'space' in choice or 'leave' in choice:
            Normal_end()
        elif choice == '3' or 'push' in choice:
            Bad_end3()
        else:
            print("You spend too much time to decide what to do. Your body is freezing.")
            Normal_end()
        # End of nested conditional
    elif choice == '2'or 'jump' in choice or 'from the ship now' in choice:
        Bad_end4()
    # Error handling
    else:
        print("Sorry, I don't understand your choice. Please try again.\n")
        input(prompt ='<Press any key to continue>\n')
        Sea()
        
#Ending 1, also the best ending
def Happy_end():
    print("You've survived with Rose! Congratulations!")
    print("After arriving America, you and Rose build a happy family and have a wonderful life!")
    input(prompt ='<Press any key to exit>\n')
    exit()  
#Ending 2, also the movie's ending    
def Normal_end():
    print("Same as the movie, before you pass out, you make Rose promise that she will survive.")
    print("And she do so. She will keep this promise till the end of her life.")
    fail()
#Ending 3
def Bad_end1():
    print("Next week, you heard that Titanic sunk because it hit an iceberg, a lot of people died.")
    fail()
#Ending 4    
def Bad_end2():
    print("Next day morning, you heard that a noble young lady is missing. You will never know what did you miss last night.")
    fail()
#Ending 5
def Bad_end3():
    print("Well, you survive, but you will live the rest of your life in guilty.")
    fail()    
#Ending 6    
def Bad_end4():
    print("You hit the seawater surface heavily. Due to the drop height, you passed out. It's impossible to survive in this situation.")
    fail()
#Fail            
def fail():
    print("Thanks for playing! Try again for a better ending!")
    # Asking the player input, whether he/she wants to play it again.
    end = str.lower(input(prompt = "Input exit to exit, input any other key to start over:\t"))
    if 'exit' in end:
        exit() 
    else:
        Tavern()

Tavern()
# Out:
# You are a poor artist called Jack.
# Today, the famous Titanic is going to America
# In a tavern, you see a bunch of people gambling.
# Their bet is a third-class ticket for Titanic.
# What are you going to do?
# 1) Join gambling
# 2) Go home
